# %%
import os, re
import datetime
import dateutil

import pandas as pd
# import plotly.express as px


# Global TODO
# FIXME add in 'Author Index', 'Attendee List'
# FIXME add in Lightning talks

# %% [markdown]
# ## Generate `generated_schedule.qmd`

# %%
safe_mkdir = lambda x: None if os.path.exists(x) else os.mkdir(x) 

# setup output structure
safe_mkdir('./generated')
safe_mkdir('./generated/talks')

# %%
schedule = pd.read_excel('./data/MGM2025_manual_schedule_250226.xlsx')
schedule
# Out:
#                           Day                                       Session  \
# 0    Wednesday, March 5, 2025                                           NaN
# 1    Wednesday, March 5, 2025                                           NaN
# 2    Wednesday, March 5, 2025                                           NaN
# 3     Thursday, March 6, 2025                                           NaN
# 4     Thursday, March 6, 2025                                           NaN
# ..                        ...                                           ...
# 124     Sunday, March 9, 2025  Session 10 – Building a Stronger Maize Plant
# 125     Sunday, March 9, 2025  Session 10 – Building a Stronger Maize Plant
# 126     Sunday, March 9, 2025  Session 10 – Building a Stronger Maize Plant
# 127     Sunday, March 9, 2025                                           NaN
# 128     Sunday, March 9, 2025                                           NaN
#
#                    Chair                                               Name  \
# 0                    NaN                  OPTIONAL PRE-CONFERENCE WORKSHOPS
# 1                    NaN                     Maize Crop Germplasm Committee
# 2                    NaN                              Corn Breeding Meeting
# 3                    NaN                  OPTIONAL PRE-CONFERENCE WORKSHOPS
# 4                    NaN                              Corn Breeding Meeting
# ..                   ...                                                ...
# 124  Frank Hochholdinger  Regulation of heterosis-associated gene expres...
# 125  Frank Hochholdinger                                    Closing Remarks
# 126  Frank Hochholdinger                                            Adjourn
# 127                  NaN                     OPTIONAL POST-CONFERENCE EVENT
# 128                  NaN     Missouri Botanical Garden - Kernels of Culture
#
#                            Presenter   Link                 Location  \
# 0                                NaN    NaN                      NaN
# 1                                NaN    NaN  Missouri History Museum
# 2                                NaN    NaN               Midway 1&2
# 3                                NaN    NaN                      NaN
# 4                                NaN    NaN               Midway 3&4
# ..                               ...    ...                      ...
# 124  Marion Pitz, University of Bonn  [T28]           Grand Ballroom
# 125                              NaN    NaN           Grand Ballroom
# 126                              NaN    NaN           Grand Ballroom
# 127                              NaN    NaN                      NaN
# 128                              NaN    NaN                      NaN
#
#               StartTime             EndTime
# 0   2025-03-05 08:00:00 2025-03-05 18:00:00
# 1   2025-03-05 08:30:00 2025-03-05 11:30:00
# 2   2025-03-05 13:00:00 2025-03-05 18:00:00
# 3   2025-03-06 08:00:00 2025-03-06 18:00:00
# 4   2025-03-06 08:00:00 2025-03-06 17:00:00
# ..                  ...                 ...
# 124 2025-03-09 11:20:00 2025-03-09 11:40:00
# 125 2025-03-09 11:40:00 2025-03-09 11:58:00
# 126 2025-03-09 11:58:00 2025-03-09 11:59:00
# 127 2025-03-10 13:00:00 2025-03-10 15:00:00
# 128 2025-03-10 13:00:00 2025-03-10 15:00:00
#
# [129 rows x 9 columns]

# %%
# # option 2 markdown tables
# out = []
# current = {e:'' for e in ['Day', 'Session', 'Chair']}

# table_header = """
# |  |        |   |  
# |:-|--------|--:|"""
# # for i in range(20):
# for i in schedule.index:
#     d = schedule.loc[i, ].to_dict()

#     if not current['Day'] == d['Day']:
#         if out != []:
#             out.append('\n\n')
#         out.append(f"## {d['Day']}")
#         current['Day'] = d['Day']

#     if not ((current['Session'] == d['Session']) or
#             (pd.isna(current['Session']) == pd.isna(d['Session']))):
#         if not pd.isna(d['Session']):
#             out.append('\n')
#             out.append(f"### {d['Session']}")
#             out.append(f"\n**{d['Chair']}**")
#         current['Session'] = d['Session']
#         current['Chair'] = d['Chair']

#     # Tweak this to allow for NaT where we have only one time available. 
#     # str_time = f"{ d['StartTime'].strftime('%H:%M') } - { d['EndTime'].strftime('%H:%M') }"
#     times = (d['StartTime'], d['EndTime'])
#     def istime(x):
#         return type(x) == pd._libs.tslibs.timestamps.Timestamp

#     times = [e.strftime('%H:%M') if istime(e) else '' for e in times]
#     times = [e for e in times if e  != '']

#     str_time = ' - '.join(times)


#     x_or_blank = lambda x : x if not pd.isna(x) else ''
    
#     str_name = x_or_blank(d['Name'])
#     str_pres = x_or_blank(d['Presenter'])
#     str_link = x_or_blank(d['Link'])

#     # convert to link 
#     str_link = str_link if str_link == '' else str_link
#     if str_link != '':
#         if re.match('\[.+\]', str_link):
#             str_link = f"{str_link}(/generated/talks/{str_link.replace('[', '').replace(']', '')}/index.qmd)"

#     str_loc = x_or_blank(d['Location'])

#     if out[-1][0] != '|':
#         out.append(table_header)
#     out.append(f"| {str_time} | {str_name} | {str_pres} {str_link} {str_loc} |")

# out = '\n'.join(out)

# %%
# qmd_content = """---
# title: "Schedule of Events"
# ---

# ::: {.callout-note appearance="simple" icon="false"}
# ## Note:

# Talks will be held in the Ballroom A Posters will be displayed in the Ballroom B&C
# :::

# """+out

# with open('./generated_schedule.qmd', 'w') as f:
#     f.writelines(qmd_content)

# %%
schedule.Link = schedule.Link.str.replace('[', '').str.replace(']', '')

# %%
schedule.to_csv('./generated/schedule.csv', index=None)

# %% [markdown]
# ## Set up Structure

# %%
safe_mkdir = lambda x: None if os.path.exists(x) else os.mkdir(x) 

# setup output structure
safe_mkdir('./generated')
safe_mkdir('./generated/talks')

qmd_content = """---
title: "Presentation Abstracts"
listing:
  contents:
    - "./"
  sort: "date"
  type: grid
  categories: true
  sort-ui: false
  filter-ui: false
page-layout: full
title-block-banner: true
editor: source
---
"""

with open('./generated/talks/index.qmd', 'w') as f:
    f.writelines(qmd_content)

# %%
# data = {e:pd.read_excel(
#     './data/MM2024-data.xlsx',
#     sheet_name=e) for  e in ['Posters', 'Talks', 'Author Index', 'Attendee List']}

data = {e:pd.read_excel(
    './data/MGM2025-Abstracts_v4.xlsx',
    sheet_name=e) for  e in ['Posters', 'Talks', 'Keynote Speakers', 'Lightning Talks', 'Author Index', 'Attendee List']}

# %% [markdown]
# ### Write out Talks

# %%
Talks = data['Talks']

out = []

callout = '::: {.callout-note collapse="true"}'
callout_dots = ':::'

# clean_category = lambda x: re.findall(r'>\D+</', x)[0].replace('>', '').replace('</', '').strip()

current_category = ''
for i in Talks.index:
    d = Talks.loc[i, ].to_dict()

    # i_category = clean_category(d['CATEGORY'])
    # if current_category != i_category:
    #     out.append(f"""\n\n# {i_category}\n\n""")
    #     current_category = i_category


    out.append( f"""
## {d['TALK']}: {d['TITLE']}
{d['CATEGORY']}
[{d['PRESENTER_FIRST_NAME']} {d['PRESENTER_LAST_NAME']}](mailto:{d['PRESENTER_EMAIL']})

{callout}
## Author List
{d['AUTHOR_LIST']}

{d['AFFILIATION_LIST']}
{callout_dots}

{callout}
## Abstract

{d['ABSTRACT']}
{callout_dots}
"""
    )

# %%
qmd_content = """---
title: "Presentations"
format:
  html:
    toc: true
    toc-depth: 1
---
"""+''.join(out)

with open('./generated_talks.qmd', 'w') as f:
    f.writelines(qmd_content)

# %% [markdown]
# ## Repeat with posters

# %%
Posters = data['Posters']

out = []

callout = '::: {.callout-note collapse="true"}'
callout_dots = ':::'

clean_category = lambda x: re.findall(r'>\D+</', x)[0].replace('>', '').replace('</', '').strip()

current_category = ''
for i in Posters.index:
    d = Posters.loc[i, ].to_dict()

    i_category = clean_category(d['CATEGORY'])
    if current_category != i_category:
        out.append(f"""\n\n# {i_category}\n\n""")
        current_category = i_category

    out.append( f"""
## {d['POSTER']}: {d['TITLE']}
{d['CATEGORY']}
[{d['PRESENTER_FIRST_NAME']} {d['PRESENTER_LAST_NAME']}](mailto:{d['PRESENTER_EMAIL']}) ({d['PRESENTER_ROLE']})

{callout}
## Author List
{d['AUTHOR_LIST']}

{d['AFFILIATION_LIST']}
{callout_dots}

{callout}
## Abstract

{d['ABSTRACT']}
{callout_dots}
"""
    )

# %%
qmd_content = """---
title: "Posters"
format:
  html:
    toc: true
    toc-depth: 1
---"""+''.join(out)

with open('./generated_poster_list.qmd', 'w') as f:
    f.writelines(qmd_content)

# %% [markdown]
# ## Repeat with 'Lightning Talks'

# %%
data['Lightning Talks'].head()
#
# Out:
#   LIGHTNING TALK   ID                                           CATEGORY  \
# 0             L1  135  <font color="#663399">Computational and Large-...
# 1             L2  336  <font color="#339966">Cell and Developmental B...
# 2             L3  116  <font color="#339966">Cell and Developmental B...
# 3             L4  138  <font color="#663399">Computational and Large-...
# 4             L5  182  <font color="#663399">Computational and Large-...
#
#    YEAR                                              TITLE  \
# 0  2025  Candidate genes underlying a major QTL qshgd1 ...
# 1  2025  A high-resolution, meristem stage-specific sin...
# 2  2025  Chemical imaging reveals metabolic responses t...
# 3  2025  Predictive modeling of pollen fitness phenotyp...
# 4  2025  Archaeological Bolivian maize genomes suggest ...
#
#                             JOURNAL  VOLUME  \
# 0  Maize Genetics Meeting Abstracts      67
# 1  Maize Genetics Meeting Abstracts      67
# 2  Maize Genetics Meeting Abstracts      67
# 3  Maize Genetics Meeting Abstracts      67
# 4  Maize Genetics Meeting Abstracts      67
#
#                                             ABSTRACT GENES GENE_MODELS  \
# 0  Doubled haploid (DH) technology accelerates pl...   NaN         NaN
# 1  Maize productivity depends on the precise regu...   NaN         NaN
# 2  Metabolite signaling regulates many developmen...   NaN         NaN
# 3  The male gametophyte of flowering plants, prim...   NaN         NaN
# 4  Previous archaeological and anthropological st...   NaN         NaN
#
#                                          AUTHOR_LIST  \
# 0  <a href='mailto:yueliu@iastate.edu'>Liu, Yue</...
# 1  <a href='mailto:xjkxu@ucdavis.edu'>Xu, Xiaosa<...
# 2  <a href='mailto:asama@ucsd.edu'>Sama, Andrea M...
# 3  <a href='mailto:muellese@oregonstate.edu'>Muel...
# 4  <a href='mailto:chenhua9@msu.edu'>Chen, Huan</...
#
#                                     AFFILIATION_LIST PRESENTER_FIRST_NAME  \
# 0  <sup>1</sup>Department of Agronomy, Iowa State...                  Yue
# 1  <sup>1</sup>Department of Plant Biology, Unive...               Xiaosa
# 2  <sup>1</sup>University of California, San Dieg...               Andrea
# 3  <sup>1</sup>Department of Botany and Plant Pat...            Sebastian
# 4  <sup>1</sup>Department of Genetics and Genome ...                 Huan
#
#   PRESENTER_LAST_NAME           PRESENTER_EMAIL          PRESENTER_ROLE
# 0                 Liu        yueliu@iastate.edu        Graduate Student
# 1                  Xu         xjkxu@ucdavis.edu  Principal Investigator
# 2                Sama            asama@ucsd.edu        Graduate Student
# 3             Mueller  Muellese@oregonstate.edu        Graduate Student
# 4                Chen          chenhua9@msu.edu                 Postdoc

# %%
Lightning = data['Lightning Talks']

out = []

callout = '::: {.callout-note collapse="true"}'
callout_dots = ':::'

clean_category = lambda x: re.findall(r'>\D+</', x)[0].replace('>', '').replace('</', '').strip()

current_category = ''
for i in Lightning.index:
    d = Lightning.loc[i, ].to_dict()

    i_category = clean_category(d['CATEGORY'])
    if current_category != i_category:
        out.append(f"""\n\n# {i_category}\n\n""")
        current_category = i_category

    out.append( f"""
## {d['LIGHTNING TALK']}: {d['TITLE']}
{d['CATEGORY']}
[{d['PRESENTER_FIRST_NAME']} {d['PRESENTER_LAST_NAME']}](mailto:{d['PRESENTER_EMAIL']}) ({d['PRESENTER_ROLE']})

{callout}
## Author List
{d['AUTHOR_LIST']}

{d['AFFILIATION_LIST']}
{callout_dots}

{callout}
## Abstract

{d['ABSTRACT']}
{callout_dots}
"""
    )

# %%
qmd_content = """---
title: "Lightning Talks"
format:
  html:
    toc: true
    toc-depth: 1
---"""+''.join(out)

with open('./generated_lightning_list.qmd', 'w') as f:
    f.writelines(qmd_content)

# %% [markdown]
# ## Repeat with 'Keynote Speakers'

# %%
data['Keynote Speakers']
# Out:
#   KEYNOTE   ID                                           CATEGORY  YEAR  \
# 0     KS1    5  <font color="#FF0066">Evolution and Population...  2025
# 1     KS2   16  <font color="#993366">Education & Outreach</font>  2025
# 2     KS3    0                            McClintock Presentation  2025
# 3     KS4  343  <font color="#663399">Computational and Large-...  2025
# 4     KS5  354  <font color="#339966">Cell and Developmental B...  2025
#
#                                                TITLE  \
# 0  Genes, jeans, genomes, and the wondrous cycles...
# 1  Input, Insurance, Objective: Reflections on di...
# 2                       Why do we do maize genetics?
# 3                   You need a real maize geneticist
# 4  Environmental integration with root cell type ...
#
#                             JOURNAL  VOLUME  \
# 0  Maize Genetics Meeting Abstracts      67
# 1  Maize Genetics Meeting Abstracts      67
# 2  Maize Genetics Meeting Abstracts      67
# 3  Maize Genetics Meeting Abstracts      67
# 4  Maize Genetics Meeting Abstracts      67
#
#                                             ABSTRACT  GENES  GENE_MODELS  \
# 0  One of the signal realizations of the genomics...    NaN          NaN
# 1  Today, diversity is an established organizatio...    NaN          NaN
# 2  Each of us has a unique journey into maize gen...    NaN          NaN
# 3  Plant growth and water use are interrelated pr...    NaN          NaN
# 4  A plant’s roots serve as a major line of defen...    NaN          NaN
#
#                                          AUTHOR_LIST  \
# 0  <a href='mailto:jfw@iastate.edu'>Wendel, Jonat...
# 1  <a href='mailto:hacurry@gatech.edu'>Curry, Hel...
# 2  <a href='mailto:ed.buckler@usda.gov'>Buckler, ...
# 3  <a href='mailto:ibaxter@danforthcenter.org'>Ba...
# 4  <a href='mailto:sbrady@ucdavis.edu'>Brady, Sio...
#
#                                     AFFILIATION_LIST PRESENTER_FIRST_NAME  \
# 0  <sup>1</sup>Iowa State University, Ames, Iowa ...             Jonathan
# 1  <sup>1</sup>Edward Buckler, USDA-ARS, Ithaca, ...           Helen Anne
# 2  <sup>1</sup>Georgia Institute of Technology; A...               Edward
# 3  <sup>1</sup>Donald Danfroth Plant Science Cent...                 Ivan
# 4  <sup>1</sup>Howard Hughes Medical Institute, U...              Siobhan
#
#   PRESENTER_LAST_NAME             PRESENTER_EMAIL          PRESENTER_ROLE
# 0              Wendel             jfw@iastate.edu  Principal Investigator
# 1               Curry          hacurry@gatech.edu  Principal Investigator
# 2             Buckler         ed.buckler@usda.gov  Principal Investigator
# 3              Baxter  ibaxter@danforthcenter.org  Principal Investigator
# 4               Brady          sbrady@ucdavis.edu  Principal Investigator

# %%
Keynotes = data['Keynote Speakers']

out = []

callout = '::: {.callout-note collapse="true"}'
callout_dots = ':::'

clean_category = lambda x: re.findall(r'>\D+</', x)[0].replace('>', '').replace('</', '').strip()

current_category = ''
for i in Keynotes.index:
    d = Keynotes.loc[i, ].to_dict()

    out.append( f"""
## {d['KEYNOTE']}: {d['TITLE']}
{d['CATEGORY']}
[{d['PRESENTER_FIRST_NAME']} {d['PRESENTER_LAST_NAME']}](mailto:{d['PRESENTER_EMAIL']}) ({d['PRESENTER_ROLE']})

{callout}
## Author List
{d['AUTHOR_LIST']}

{d['AFFILIATION_LIST']}
{callout_dots}

{callout}
## Abstract

{d['ABSTRACT']}
{callout_dots}
"""
    )

# %%
qmd_content = """---
title: "Keynotes"
format:
  html:
    toc: true
    toc-depth: 1
---"""+''.join(out)

with open('./generated_keynote_list.qmd', 'w') as f:
    f.writelines(qmd_content)

# %% [markdown]
# ## Write out presentation/poster pages

# %%
# setup output structure
safe_mkdir('./generated')
safe_mkdir('./generated/posters')
safe_mkdir('./generated/talks')

# write index qmd pages
qmd_content = """---
title: "Posters"
listing:
  contents:
    - "./"
  type: grid
  categories: true
  sort-ui: false
  filter-ui: false
page-layout: full
title-block-banner: true
editor: source
---
"""

with open('./generated/posters/index.qmd', 'w') as f:
    f.writelines(qmd_content)

qmd_content = """---
title: "Presentation Abstracts"
listing:
  contents:
    - "./"
  sort: "date"
  type: grid
  categories: true
  sort-ui: false
  filter-ui: false
page-layout: full
title-block-banner: true
editor: source
---
"""

with open('./generated/talks/index.qmd', 'w') as f:
    f.writelines(qmd_content)

# %%
category_2_image = {
    'Computational and Large-Scale Biology': 'https://upload.wikimedia.org/wikipedia/commons/e/e5/ENIAC-changing_a_tube.jpg',
    'Cell and Developmental Biology': 'https://upload.wikimedia.org/wikipedia/commons/c/c1/Protective_Coleoptile_Tip_in_Zea_Mays_Embryo_%2847691344541%29.jpg',
    'Biochemical and Molecular Genetics': 'https://upload.wikimedia.org/wikipedia/commons/0/05/DNA_base-pair_diagram.jpg',
    'Transposons & Epigenetics': 'https://upload.wikimedia.org/wikipedia/commons/b/b3/Genetic_corn.jpg',
    'Quantitative Genetics & Breeding': 'https://upload.wikimedia.org/wikipedia/commons/5/5e/Aztec_Diet_Basket_of_Corn_%289755332575%29.jpg',
    'Education & Outreach': 'https://upload.wikimedia.org/wikipedia/commons/6/69/Leiden_University_Library_-_Seikei_Zusetsu_vol._19%2C_page_019_-_%E7%8E%89%E8%9C%80%E9%BB%8D_-_Zea_mays_L.%2C_1804.jpg',
    'Cytogenetics': 'https://upload.wikimedia.org/wikipedia/commons/a/ab/Angiosperm_Morphology_The_Closed_and_Collateral_Vascular_Bundle_in_Zea_%2837215761790%29.jpg',
    'Evolution and Population Genetics': 'https://upload.wikimedia.org/wikipedia/commons/9/9a/CollapsedtreeLabels-simplified-fi.svg'
}

# %%
# Write poster presentation info ----

# for i in data['Posters'].index:
#     d = data['Posters'].loc[i, ].to_dict()

#     # if we have a multi-category case":
#     # import re
#     # categories = re.findall(r'>.+<', d['CATEGORY'])
#     # categories = [e.replace('>', '').replace('<', '').strip() for e in categories]
#     # categories

#     qmd_header = f"""---
# title: "{d['TITLE']}"
# subtitle: "{d['POSTER']}"
# author: "{d['PRESENTER_FIRST_NAME']+' '+d['PRESENTER_LAST_NAME']}"
# date: ""
# image: "{category_2_image[d['CATEGORY'].split('>')[1].split('<')[0].strip()]}"
# categories: 
# - {d['CATEGORY'].split('>')[1].split('<')[0].strip()}
# - {'Even Numbered' if (int(d['POSTER'].replace('P', '')) % 2 == 0) else 'Odd Numbered'}
# freeze: true
# editor: source
# markdown: 
#     wrap: 72
# ---"""

#     qmd_content = '\n\n'.join([
#         qmd_header,
#         d['ABSTRACT'],
#         d['AUTHOR_LIST'],
#         d['AFFILIATION_LIST']])

#     save_to = f"./generated/posters/{d['POSTER']}/index.qmd"

#     # make output dir if missing
#     safe_mkdir('/'.join(save_to.split('/')[0:-1]))

#     with open(save_to, 'w') as f:
#         f.writelines(qmd_content)

# %%
# Write talk presentation info ----

# for i in data['Talks'].index:
#     d = data['Talks'].loc[i, ].to_dict()

#     qmd_header = f"""---
# title: "{d['TITLE']}"
# subtitle: "{d['TALK']}"
# author: "{d['PRESENTER_FIRST_NAME']+' '+d['PRESENTER_LAST_NAME']}"
# date: ""
# image: "{category_2_image[d['CATEGORY'].split('>')[1].split('<')[0].strip()]}"
# categories: 
# - {d['CATEGORY'].split('>')[1].split('<')[0].strip()}
# freeze: true
# editor: source
# markdown: 
#     wrap: 72
# ---"""

#     qmd_content = '\n\n'.join([
#         qmd_header,
#         d['ABSTRACT'],
#         d['AUTHOR_LIST'],
#         d['AFFILIATION_LIST']])

#     save_to = f"./generated/talks/{d['TALK']}/index.qmd"

#     # make output dir if missing
#     safe_mkdir('/'.join(save_to.split('/')[0:-1]))

#     with open(save_to, 'w') as f:
#         f.writelines(qmd_content)

# %% [markdown]
# ## Create linking information for talks and posters

# %%
list(Lightning)
# Out:
# ['LIGHTNING TALK',
#  'ID',
#  'CATEGORY',
#  'YEAR',
#  'TITLE',
#  'JOURNAL',
#  'VOLUME',
#  'ABSTRACT',
#  'GENES',
#  'GENE_MODELS',
#  'AUTHOR_LIST',
#  'AFFILIATION_LIST',
#  'PRESENTER_FIRST_NAME',
#  'PRESENTER_LAST_NAME',
#  'PRESENTER_EMAIL',
#  'PRESENTER_ROLE']

# %%
def find_headers(qmd_path = './generated_talks.qmd', talk_nums = []):
    # get all of the header lines
    with open(qmd_path, 'r') as f:
        dat = [e for e in f.readlines() if re.match(r'#+', e)]
    headers = [[e.strip() for e in dat if re.findall(f'{tnum}:', e)][0] for tnum in talk_nums]
    headers = [(
        h
        # disallowed characters
        .replace('#', '')
        .replace(':', '')
        .replace('(', '')
        .replace(')', '')
        .replace('.', '')
        .replace('?', '')
        # format as part of address
        .strip()
        .lower()
        .replace(' ', '-')
        ) for h in headers]

    return   [f"{qmd_path.replace('qmd', 'html')}#{h}" for h in headers]

schedule_links = pd.concat([
    pd.DataFrame({
        'Type': 'Talk', 
        'Name': Talks['TALK'].tolist(),
        'Header': find_headers(qmd_path = './generated_talks.qmd', talk_nums = Talks['TALK'].tolist())
        }),
        pd.DataFrame({
        'Type': 'Poster', 
        'Name': Posters['POSTER'].tolist(),
        'Header': find_headers(qmd_path = './generated_poster_list.qmd', talk_nums = Posters['POSTER'].tolist())
        }),
        pd.DataFrame({
        'Type': 'Keynote', 
        'Name': Keynotes['KEYNOTE'].tolist(),
        'Header': find_headers(qmd_path = './generated_keynote_list.qmd', talk_nums = Keynotes['KEYNOTE'].tolist())
        }),
        pd.DataFrame({
        'Type': 'Lightning', 
        'Name': Lightning['LIGHTNING TALK'].tolist(),
        'Header': find_headers(qmd_path = './generated_lightning_list.qmd', talk_nums = Lightning['LIGHTNING TALK'].tolist())
        })
        ]).reset_index(drop = True)


schedule_links.to_csv('./generated/schedule_links.csv', index=None)

# %%
<a href="./generated_keynote_list.html#ks1-genes,-jeans,-genomes,-and-the-wondrous-cycles-of-polyploidy-in-plants" style="     " >KS1</a>
<a href="./generated_lightning_list.html#l1-candidate-genes-underlying-a-major-qtl-qshgd1-causing-spontaneous-haploid-genome-doubling-in-maize-a427" style="     " >L1</a>
<a href="./generated_talks.html#t1-vgt1-as-enhancer-of-zmrap27-impacts-flowering-time-and-gene-regulatory-networks-involved-in-jasmonate-signaling-in-maize" style="     " >T1</a>

"./generated_lightning_list.html#l1-candidate-genes-underlying-a-major-qtl-qshgd1-causing-spontaneous-haploid-genome-doubling-in-maize-a427"
  #generated_lightning_list.html#l1-candidate-genes-underlying-a-major-qtl-qshgd1-causing-spontaneous-haploid-genome-doubling-in-maize-a427
